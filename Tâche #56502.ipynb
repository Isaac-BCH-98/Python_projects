# %%
# !pip install beautifulsoup4
# !pip install selenium
# !pip install requests
# !pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse

# Fonction pour récupérer tous les liens internes d'une page
def get_internal_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    domain = urlparse(url).netloc
    internal_links = []

    for link in soup.find_all('a'):
        href = link.get('href')
        if href and domain in href:
            internal_links.append(href)

    return internal_links

# Fonction pour récupérer tous les contenus textuels des pages
def get_site_contents(url):
    domain = urlparse(url).netloc
    visited_urls = set()
    stack = [url]
    contents = []

    while stack:
        current_url = stack.pop()

        if current_url in visited_urls:
            continue

        visited_urls.add(current_url)

        response = requests.get(current_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        text = soup.get_text()

        contents.append(text)

        internal_links = get_internal_links(current_url)

        for link in internal_links:
            stack.append(link)

    return contents

# URL de départ
starting_url = 'https://www.edlitera.com'

# Récupérer tous les contenus textuels des pages du site
site_contents = get_site_contents(starting_url)

# Concaténer tous les contenus textuels en un seul texte
output_text = '\n'.join(site_contents)

# Afficher le résultat
print(output_text)
# Out:
#       Edlitera
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# edlitera
#
#
# Login
# Get Started
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Training
#
#
# For Individuals
#
#
# Blog
#
#
# Consulting
#
#
#
#
#
#
# edlitera
#
#
#
# Training
#
#
# For Individuals
#
#
# Blog
#
#
# Consulting
#
#
#
# Login
# Get Started
#
#
#
#
#
#
# Edlitera works best when JavaScript is enabled. Click to learn more.
#
#
#
#
#
#
#
#
# This site uses cookies.
#
#
#
# By continuing to use this site, you are agreeing to our use of cookies. For more information, please review our Terms and Privacy.
#
#
# OK
#
#
#
#
#
#
#
#
#           Future-Proof Your Organization
#
#
#           We provide onsite and live-online training and consulting services in Python Programming, Data Analysis, Machine Learning, Data Science and Data Engineering.
#
#
#
#             Training Services
#
#
#             Consulting Services
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               For Companies
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse

# Fonction pour récupérer tous les liens internes d'une page
def get_internal_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    domain = urlparse(url).netloc
    internal_links = []

    for link in soup.find_all('a'):
        href = link.get('href')
        if href and domain in href:
            internal_links.append(href)

    return internal_links

# Fonction pour récupérer tous les contenus textuels des pages
def get_site_contents(url):
    domain = urlparse(url).netloc
    visited_urls = set()
    stack = [url]
    contents = []

    while stack:
        current_url = stack.pop()

        if current_url in visited_urls:
            continue

        visited_urls.add(current_url)

        response = requests.get(current_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        text = soup.get_text()

        contents.append(text)

        internal_links = get_internal_links(current_url)

        for link in internal_links:
            stack.append(link)

    return contents

# Fonction principale pour récupérer le contenu textuel du site
def get_site_text(url):
    site_contents = get_site_contents(url)
    output_text = '\n'.join(site_contents)
    return output_text

# URL de départ
starting_url = 'https://www.edlitera.com'

# Récupérer le contenu textuel du site
site_text = get_site_text(starting_url)

# Afficher le résultat
print(site_text)
# Out:
#       Edlitera
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# edlitera
#
#
# Login
# Get Started
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Training
#
#
# For Individuals
#
#
# Blog
#
#
# Consulting
#
#
#
#
#
#
# edlitera
#
#
#
# Training
#
#
# For Individuals
#
#
# Blog
#
#
# Consulting
#
#
#
# Login
# Get Started
#
#
#
#
#
#
# Edlitera works best when JavaScript is enabled. Click to learn more.
#
#
#
#
#
#
#
#
# This site uses cookies.
#
#
#
# By continuing to use this site, you are agreeing to our use of cookies. For more information, please review our Terms and Privacy.
#
#
# OK
#
#
#
#
#
#
#
#
#           Future-Proof Your Organization
#
#
#           We provide onsite and live-online training and consulting services in Python Programming, Data Analysis, Machine Learning, Data Science and Data Engineering.
#
#
#
#             Training Services
#
#
#             Consulting Services
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               For Companies
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse
from openpyxl import Workbook

# Fonction pour récupérer tous les liens internes d'une page
def get_internal_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    domain = urlparse(url).netloc
    internal_links = []

    for link in soup.find_all('a'):
        href = link.get('href')
        if href and domain in href:
            internal_links.append(href)

    return internal_links

# Fonction pour récupérer tous les contenus textuels des pages
def get_site_contents(url):
    domain = urlparse(url).netloc
    visited_urls = set()
    stack = [url]
    contents = []

    while stack:
        current_url = stack.pop()

        if current_url in visited_urls:
            continue

        visited_urls.add(current_url)

        response = requests.get(current_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        text = soup.get_text()

        contents.append(text)

        internal_links = get_internal_links(current_url)

        for link in internal_links:
            stack.append(link)

    return contents

# Fonction principale pour récupérer le contenu textuel du site
def get_site_text(url):
    site_contents = get_site_contents(url)
    output_text = '\n'.join(site_contents)
    return output_text

# URL de départ
starting_url = 'https://www.edlitera.com'

# Récupérer le contenu textuel du site
site_text = get_site_text(starting_url)

# Créer un nouveau classeur Excel
wb = Workbook()
sheet = wb.active

# Écrire le contenu textuel dans la première cellule
sheet['A1'] = site_text

# Enregistrer le classeur Excel
wb.save('site_contents.xlsx')

print("Les données ont été enregistrées dans le fichier site_contents.xlsx.")
# Out:
# Les données ont été enregistrées dans le fichier site_contents.xlsx.

# %%
# !pip install selenium
# !pip install beautifulsoup4
# !pip install openpyxl
# !!pip install webdriver_manager
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 60.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 28.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.6 MB/s eta 0:00:00
# ...
# ['Collecting webdriver_manager',
#  '  Downloading webdriver_manager-3.8.6-py2.py3-none-any.whl (27 kB)',
#  'Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from webdriver_manager) (2.27.1)',
#  'Collecting python-dotenv (from webdriver_manager)',
#  '  Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)',
#  'Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from webdriver_manager) (4.65.0)',
#  'Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from webdriver_manager) (23.1)',
#  'Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->webdriver_manager) (1.26.16)',
# ...

# %%
# !pip install beautifulsoup4
# !pip install numpy
# !pip install requests
# !pip install spacy
# !pip install trafilatura
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.8/837.8 kB 38.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.8/263.8 kB 24.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 kB 26.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.12
#     Uninstalling charset-normalizer-2.0.12:
#       Successfully uninstalled charset-normalizer-2.0.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from bs4 import BeautifulSoup
import json
import numpy as np
import requests
from requests.models import MissingSchema
import spacy
import trafilatura

# %%
urls = ['https://www.edlitera.com/',
      'https://openclassrooms.com/',]

# %%
data = {}

for url in urls:
    # 1. Obtain the response:
    resp = requests.get(url)

    # 2. If the response content is 200 - Status Ok, Save The HTML Content:
    if resp.status_code == 200:
        data[url] = resp.text

# %%
def beautifulsoup_extract_text_fallback(response_content):

    '''
    This is a fallback function, so that we can always return a value for text content.
    Even for when both Trafilatura and BeautifulSoup are unable to extract the text from a
    single URL.
    '''

    # Create the beautifulsoup object:
    soup = BeautifulSoup(response_content, 'html.parser')

    # Finding the text:
    text = soup.find_all(text=True)

    # Remove unwanted tag elements:
    cleaned_text = ''
    blacklist = [
        '[document]',
        'noscript',
        'header',
        'html',
        'meta',
        'head',
        'input',
        'script',
        'style',]

    # Then we will loop over every item in the extract text and make sure that the beautifulsoup4 tag
    # is NOT in the blacklist
    for item in text:
        if item.parent.name not in blacklist:
            cleaned_text += '{} '.format(item)

    # Remove any tab separation and strip the text:
    cleaned_text = cleaned_text.replace('\t', '')
    return cleaned_text.strip()


def extract_text_from_single_web_page(url):
    downloaded_url = trafilatura.fetch_url(url)
    try:
        a = trafilatura.extract(downloaded_url, output_format='json', with_metadata=True, include_comments=False,
                                date_extraction_params={'extensive_search': True, 'original_date': True})
    except AttributeError:
        a = trafilatura.extract(downloaded_url, output_format='json', with_metadata=True,
                                date_extraction_params={'extensive_search': True, 'original_date': True})
    if a:
        json_output = json.loads(a)
        return json_output['text']
    else:
        try:
            resp = requests.get(url)
            if resp.status_code == 200:
                return beautifulsoup_extract_text_fallback(resp.content)
            else:
                return np.nan
        except MissingSchema:
            return np.nan

# %%
import requests
import trafilatura
from bs4 import BeautifulSoup
import json
import numpy as np

# Define the functions beautifulsoup_extract_text_fallback and extract_text_from_single_web_page here

single_url = 'https://www.edlitera.com/'
text = extract_text_from_single_web_page(single_url)
print(text)
# Out:
# Future-Proof Your Organization
# We provide onsite and live-online training and consulting services in Python Programming, Data Analysis, Machine Learning, Data Science and Data Engineering.
# ANZ Bank Training
# Edlitera was selected to design and deliver a customized training program for the New York City group of ANZ Bank.
# "The projects were especially well delivered and were a highlight for the group. The ability to use real work projects and implement the learnings after the training session was something that really stood out."See Case Study
# Marino VedanayagamVP, Risk and Assurance
# Consulting services
# Everyone gathers data. How you use it to drive profits is your competitive edge. Whether you're just getting started with a big data initiative or taking your current strategy to the next level, we can help you go from data to insights.
# Marketing Effectiveness
# Reduce customer acquisition costs and increase conversions.
# People Analytics
# ...

# %%
urls = urls + ['https://www.edlitera.com/']

text_content = [extract_text_from_single_web_page(url) for url in urls]

print(text_content[1])
# Out:
# ERROR:trafilatura.core:no metadata for URL None
# WARNING:trafilatura.core:discarding data for url: None
# <ipython-input-30-5f5c880537d3>:13: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   text = soup.find_all(text=True)
# OpenClassrooms
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Aller au contenu
#
#
#  Choisir la langue
#
#
#  Aller à la recherche
#
#
#
#
#
#
#
#
#
#
#
#
#
#  OpenClassrooms.com
#
#
#
#
#
#
#  Formations
#
#  Pour les entreprises
#
#
#
#
#
#
#
#
#  [if lt IE 10]>
#         <div class="alertMessage">
#         <span class="bullet bullet--small bullet--orange alertMessage__icon"> <i class="icon-exclamation"></i></span>
#         <p class="alertMessage__text">
#             Vous utilisez un navigateur obsolète, veuillez le <a href="https://browser-update.org/update.html">mettre à jour</a>.
#         </p>
#     </div>
#     <![endif]
#
#
#
#
# Vous utilisez un navigateur obsolète, veuillez le  mettre à jour .
#
#
#
#
# ...

# %%
print(text_content[-1:])
# Out:
# ['Future-Proof Your Organization\nWe provide onsite and live-online training and consulting services in Python Programming, Data Analysis, Machine Learning, Data Science and Data Engineering.\nANZ Bank Training\nEdlitera was selected to design and deliver a customized training program for the New York City group of ANZ Bank.\n"The projects were especially well delivered and were a highlight for the group. The ability to use real work projects and implement the learnings after the training session was something that really stood out."See Case Study\nMarino VedanayagamVP, Risk and Assurance\nConsulting services\nEveryone gathers data. How you use it to drive profits is your competitive edge. Whether you\'re just getting started with a big data initiative or taking your current strategy to the next level, we can help you go from data to insights.\nMarketing Effectiveness\nReduce customer acquisition costs and increase conversions.\nPeople Analytics\nKeep your finger on the pulse and ret
# ...

# %%
cleaned_textual_content = [text for text in text_content if str(text) != 'nan']

# %%
nlp = spacy.load("en_core_web_sm")

# %%
for cleaned_text in cleaned_textual_content:
    # 1. Create an NLP document with Spacy:
    doc = nlp(cleaned_text)
    # 2. Spacy has tokenised the text content:
    print(f"This is a spacy token: {doc[0]}")
    # 3. Extracting the word count per text document:
    print(f"The estimated word count for this document is: {len(doc)}.")
    # 4. Extracting the number of sentences:
    print(f"The estimated number of sentences in the document is: {len(list(doc.sents))}")
    print('\n')
# Out:
# This is a spacy token: Future
# The estimated word count for this document is: 439.
# The estimated number of sentences in the document is: 23
#
#
# This is a spacy token: OpenClassrooms
# The estimated word count for this document is: 125.
# The estimated number of sentences in the document is: 5
#
#
# This is a spacy token: Future
# The estimated word count for this document is: 439.
# The estimated number of sentences in the document is: 23

# %%
for cleaned_text in cleaned_textual_content:
  print(cleaned_text)
# Out:
# Future-Proof Your Organization
# We provide onsite and live-online training and consulting services in Python Programming, Data Analysis, Machine Learning, Data Science and Data Engineering.
# ANZ Bank Training
# Edlitera was selected to design and deliver a customized training program for the New York City group of ANZ Bank.
# "The projects were especially well delivered and were a highlight for the group. The ability to use real work projects and implement the learnings after the training session was something that really stood out."See Case Study
# Marino VedanayagamVP, Risk and Assurance
# Consulting services
# Everyone gathers data. How you use it to drive profits is your competitive edge. Whether you're just getting started with a big data initiative or taking your current strategy to the next level, we can help you go from data to insights.
# Marketing Effectiveness
# Reduce customer acquisition costs and increase conversions.
# People Analytics
# ...

# %%
import requests
from bs4 import BeautifulSoup

def crawl_website(url):
    # Faire une requête GET pour obtenir le contenu HTML de la page
    response = requests.get(url)
    if response.status_code == 200:
        # Utiliser BeautifulSoup pour analyser le contenu HTML
        soup = BeautifulSoup(response.content, 'html.parser')

        # Exemple : Extraire tous les liens de la page
        links = soup.find_all('a')
        for link in links:
            href = link.get('href')
            if href:
                print(href)
    else:
        print('Erreur lors de la requête GET:', response.status_code)

# Exemple d'utilisation : crawler le site web d'OpenAI
crawl_website('https://elearning.univ-blida.dz/')
# Out:
# #maincontent
# https://elearning.univ-blida.dz/login/index.php
# https://elearning.univ-blida.dz/?redirect=0
# #
# https://elearning.univ-blida.dz/?lang=_temp_1eba36df20c257a7839fb2189d531041
# https://elearning.univ-blida.dz/?lang=en
# https://elearning.univ-blida.dz/?lang=fr
# https://elearning.univ-blida.dz/?lang=ar
# #home-page-carousel
# #home-page-carousel
# https://elearning.univ-blida.dz
# https://elearning.univ-blida.dz/course/view.php?id=5303
# https://elearning.univ-blida.dz/course/view.php?id=5303
# https://elearning.univ-blida.dz/course/view.php?id=5303
# https://elearning.univ-blida.dz/course/view.php?id=5302
# https://elearning.univ-blida.dz/course/view.php?id=5302
# https://elearning.univ-blida.dz/course/view.php?id=5302
# https://elearning.univ-blida.dz/course/view.php?id=5301
# https://elearning.univ-blida.dz/course/view.php?id=5301
# https://elearning.univ-blida.dz/course/view.php?id=5301
# https://elearning.univ-blida.dz/course/view.php?id=5300
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin

def crawl_website(url):
    base_url = urlparse(url).netloc
    visited_urls = set()
    output_text = ""

    def extract_text(soup):
        nonlocal output_text
        for script in soup(["script", "style"]):
            script.extract()
        text = soup.get_text()
        lines = (line.strip() for line in text.splitlines())
        chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
        text = ' '.join(chunk for chunk in chunks if chunk)
        output_text += text + "\n"

    def crawl(url):
        nonlocal visited_urls
        visited_urls.add(url)

        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            extract_text(soup)

            # Extraire les liens de la page et les traiter récursivement
            links = soup.find_all('a', href=True)
            for link in links:
                href = link.get('href')
                if href:
                    next_url = urljoin(url, href)
                    parsed_url = urlparse(next_url)
                    if parsed_url.netloc == base_url and next_url not in visited_urls:
                        crawl(next_url)
        else:
            print('Erreur lors de la requête GET:', response.status_code)

    crawl(url)
    return output_text

# Exemple d'utilisation : crawler le site web d'OpenAI et récupérer tous les contenus textuels
text_content = crawl_website('https://www.algerietelecom.dz/')
print(text_content)
# Out:
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# ...

# %%
import requests
from bs4 import BeautifulSoup

def crawl_website(url):
    # Envoyer une requête HTTP GET pour obtenir le contenu de la page web
    response = requests.get(url)

    # Vérifier si la requête a réussi
    if response.status_code == 200:
        # Utiliser BeautifulSoup pour analyser le contenu HTML
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extraire les liens de la page
        links = soup.find_all('a')

        # Parcourir les liens et afficher leur texte et URL
        for link in links:
            link_text = link.text
            link_url = link['href']
            print(f"Texte du lien : {link_text}, URL : {link_url}")
    else:
        print("La requête a échoué.")

# Appel de la fonction crawl_website en spécifiant l'URL du site à crawler
crawl_website('https://www.iana.org/')
# Out:
# Texte du lien : Learn more., URL : about/
# Texte du lien : Domain Names, URL : /domains
# Texte du lien : Root Zone Management, URL : /domains/root
# Texte du lien : Database of Top Level Domains, URL : /domains/root/db
# Texte du lien : .int Registry, URL : /domains/int
# Texte du lien : .arpa Registry, URL : /domains/arpa
# Texte du lien : IDN Practices Repository, URL : /domains/idn-tables
# Texte du lien : Number Resources, URL : /numbers
# Texte du lien : IP Addresses & AS Numbers, URL : /numbers
# Texte du lien : Network abuse information, URL : /abuse
# Texte du lien : Protocol Assignments, URL : /protocols
# Texte du lien : Protocol Registries, URL : /protocols
# Texte du lien : Apply for an assignment, URL : /protocols/apply
# Texte du lien : Time Zone Database, URL : /time-zones
# Texte du lien : Domain Names, URL : /domains
# Texte du lien : Root Zone Registry, URL : /domains/root
# Texte du lien : .INT Registry, URL : /domains/int
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin

def crawl_website(url):
    base_url = urlparse(url).netloc
    visited_urls = set()
    output_text = ""

    def extract_text(soup):
        nonlocal output_text
        for script in soup(["script", "style"]):
            script.extract()
        text = soup.get_text()
        lines = (line.strip() for line in text.splitlines())
        chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
        text = ' '.join(chunk for chunk in chunks if chunk)
        output_text += text + "\n"

    def crawl(url):
        nonlocal visited_urls
        visited_urls.add(url)

        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            extract_text(soup)

            # Extraire les liens de la page et les traiter récursivement
            links = soup.find_all('a', href=True)
            for link in links:
                href = link.get('href')
                if href:
                    next_url = urljoin(url, href)
                    parsed_url = urlparse(next_url)
                    if parsed_url.netloc == base_url and next_url not in visited_urls:
                        crawl(next_url)
        else:
            print('Erreur lors de la requête GET:', response.status_code)

    crawl(url)
    return output_text

# Exemple d'utilisation : crawler le site web d'OpenAI et sauvegarder les contenus textuels dans un fichier
text_content = crawl_website('https://elearning.univ-blida.dz/')

# Sauvegarder le contenu textuel dans un fichier .txt
with open('contenus.txt', 'w', encoding='utf-8') as file:
    file.write(text_content)

print("Contenus sauvegardés avec succès dans le fichier contenus.txt.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-09da3d1421ee> in <cell line: 45>()
#      43
#      44 # Exemple d'utilisation : crawler le site web d'OpenAI et sauvegarder les contenus textuels dans un fichier
# ---> 45 text_content = crawl_website('https://elearning.univ-blida.dz/')
#      46
#      47 # Sauvegarder le contenu textuel dans un fichier .txt
#
# <ipython-input-14-09da3d1421ee> in crawl_website(url)
#      39             print('Erreur lors de la requête GET:', response.status_code)
#      40
# ---> 41     crawl(url)
#      42     return output_text
#      43
#
# <ipython-input-14-09da3d1421ee> in crawl(url)
#      35                     parsed_url = urlparse(next_url)
#      36                     if parsed_url.netloc == base_url and next_url not in visited_urls:
# ---> 37                         crawl(next_url)
#      38         else:
# ...
